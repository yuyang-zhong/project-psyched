# %% [markdown]
# # Project Psyched: A Closer Look Into Reproducibility In Psychological Research
#
# ## Data Analysis & Visualization Script: Part 2b - Rounding Errors
# This script for data analysis and visualization after data has been scraped from TDM Studio. This part of the project utilizes the full corpus of both #1 and #2.
#
# Author: Yuyang Zhong (2020). This work is licensed under a [Creative Commons BY-NC-SA 4.0 International
# License][cc-by].
#
# ![CC BY-NC-SA 4.0][cc-by-shield]
#
# [cc-by]: http://creativecommons.org/licenses/by/4.0/
# [cc-by-shield]: https://img.shields.io/badge/license-CC--BY--NC--SA%204.0-blue

# %% [markdown]
# #### Setup & Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import ast

from scipy import stats

# %% [markdown]
# #### Copied over from data cleaning & transformation script

# %%
in_path = "../data/raw/"
out_path = "../data/"
corpus1_stat_path = 'corpus1_stat_full.csv'
corpus2_stat_path = 'corpus2_stat_full.csv'

corpus1_stat = pd.read_csv(in_path + corpus1_stat_path, index_col = 0)
corpus2_stat = pd.read_csv(in_path + corpus2_stat_path, index_col = 0)

corpus1_stat = corpus1_stat.drop(['F_stats_SN', 't_scores_SN'], axis=1)
corpus2_stat = corpus2_stat.drop(['F_stats_SN', 't_scores_SN'], axis=1)

stats_all = corpus1_stat.append(corpus2_stat)
stats_all.head()
# Out:
#                                                           F_stats F_stats_ns  \
# 614337945.xml                                                  []         []
# 1647028895.xml                                                 []         []
# 614404963.xml   ['F(1, 6) = 0.89, p = .382', 'F(1, 63) = 17.02...         []
# 614332724.xml   ['F(10, 776) = 6.84, p   < .001', 'F(10, 722) ...         []
# 614304222.xml                                                  []         []
#
#                                                          t_scores t_scores_ns
# 614337945.xml   ['t   (41)   = 4.10,    p   < .01', 't   (41) ...          []
# 1647028895.xml                                                 []          []
# 614404963.xml                                                  []          []
# 614332724.xml                                                  []          []
# 614304222.xml                                                  []          []

# %%
df_stats = pd.DataFrame(columns=['File', 'Original', 'Type', 'Param1', 'Param2', 'Stat', 'Sign', 'Reported p-value'])

# %%
def extract_f(s):
    """
    Takes in a string of reported F statistics with p-value and extract the numeric parameters.
    
    Returns: df1, df2, x, p
    """
    extract = re.findall(
        r'Fs?\s*\(\s*(\d+)\s*\,\s*(\d+)\s*\)\s*[\<|\>|\=]\s*(\d*\.?\d*)\s*\,\s*p\s*([\<|\>|\=])\s*(\d*\.\d+)',
        s)[0]    
    
    df1 = float(extract[0])
    df2 = float(extract[1])
    
    x = float(extract[2])
    ineq = extract[3]
    p = float(extract[4])
    
    return df1, df2, x, ineq, p

def extract_t(s):
    """
    Takes in a string of reported t score with p-value and extract the numeric parameters.
    
    Returns: df, x, p
    """
    
    s = re.sub(r'−\s*', "-", s)
    extract = re.findall(
        r't\s*\((\s*\d*\s*,)?\s*(\d+)\s*\)\s*[\<|\>|\=]\s*([\−|\-]?\s*\d*\.?\d*)\s*,\s*p\s*([\<|\>|\=])\s*(\d?\.\d+)',
        s)[0]
    
    df = float(extract[1])
    x = float(extract[2].replace(" ", ""))
    ineq = extract[3]
    p = float(extract[4])
    
    return df, x, ineq, p

# %%
def extract_f_compute_add(test_type, index, s):
    ex = extract_f(s)
    return {'File': index, 
            'Original': s, 
            'Type': test_type,
            'Param1': ex[0], 
            'Param2': ex[1], 
            'Stat': ex[2], 
            'Sign': ex[3],
            'Reported p-value': ex[4]}

def extract_t_compute_add(test_type, index, s):
    ex = extract_t(s)
    return {'File': index, 
            'Original': s, 
            'Type': test_type, 
            'Param1': ex[0], 
            'Param2': None,
            'Stat': ex[1],
            'Sign': ex[2],
            'Reported p-value': ex[3]}

# %%
for col in stats_all.columns:
    stats_all[col] = stats_all[col].apply(ast.literal_eval)

# %%
count = 0

for index, row in stats_all.iterrows():
    
    if len(row['F_stats']) > 0:
        for s in row['F_stats']:
            if count % 1000 == 0:
                print(count, 'p-values captured')
            
            try:
                extract = extract_f_compute_add('f', index, s)
            except:
                pass
            else:
                df_stats = df_stats.append(extract, ignore_index=True)
            count += 1
    
    if len(row['t_scores']) > 0:
        for s in row['t_scores']:
            if count % 1000 == 0:
                print(count, 'p-values captured')
        
            try:
                extract = extract_t_compute_add('t', index, s)
            except:
                pass
            else:
                df_stats = df_stats.append(extract, ignore_index=True)
            count += 1
# Out:
# 0 p-values captured
# 1000 p-values captured
# 2000 p-values captured
# 3000 p-values captured
# 4000 p-values captured
# 5000 p-values captured
# 6000 p-values captured
# 7000 p-values captured
# 8000 p-values captured
# 9000 p-values captured
# 10000 p-values captured
# 11000 p-values captured
# 12000 p-values captured
# 13000 p-values captured
# 14000 p-values captured
# 15000 p-values captured
# 16000 p-values captured
# 17000 p-values captured
# 18000 p-values captured
# 19000 p-values captured
# 20000 p-values captured
# 21000 p-values captured
# 22000 p-values captured
# 23000 p-values captured
# 24000 p-values captured
# 25000 p-values captured
# 26000 p-values captured
# 27000 p-values captured
# 28000 p-values captured
# 29000 p-values captured
# 30000 p-values captured
# 31000 p-values captured
# 32000 p-values captured
# 33000 p-values captured
# 34000 p-values captured
# 35000 p-values captured
# 36000 p-values captured
# 37000 p-values captured
# 38000 p-values captured
# 39000 p-values captured
# 40000 p-values captured
# 41000 p-values captured
# 42000 p-values captured
# 43000 p-values captured
# 44000 p-values captured
# 45000 p-values captured
# 46000 p-values captured
# 47000 p-values captured
# 48000 p-values captured
# 49000 p-values captured
# 50000 p-values captured
# 51000 p-values captured
# 52000 p-values captured
# 53000 p-values captured
# 54000 p-values captured
# 55000 p-values captured
# 56000 p-values captured
# 57000 p-values captured
# 58000 p-values captured
# 59000 p-values captured
# 60000 p-values captured
# 61000 p-values captured
# 62000 p-values captured
# 63000 p-values captured
# 64000 p-values captured
# 65000 p-values captured
# 66000 p-values captured
# 67000 p-values captured
# 68000 p-values captured
# 69000 p-values captured
# 70000 p-values captured
# 71000 p-values captured
# 72000 p-values captured
# 73000 p-values captured
# 74000 p-values captured
# 75000 p-values captured
# 76000 p-values captured
# 77000 p-values captured
# 78000 p-values captured
# 79000 p-values captured
# 80000 p-values captured
# 81000 p-values captured
# 82000 p-values captured
# 83000 p-values captured
# 84000 p-values captured
# 85000 p-values captured
# 86000 p-values captured
# 87000 p-values captured
# 88000 p-values captured
# 89000 p-values captured
# 90000 p-values captured
# 91000 p-values captured
# 92000 p-values captured
# 93000 p-values captured
# 94000 p-values captured
# 95000 p-values captured
# 96000 p-values captured
# 97000 p-values captured
# 98000 p-values captured
# 99000 p-values captured
# 100000 p-values captured
# 101000 p-values captured
# 102000 p-values captured
# 103000 p-values captured
# 104000 p-values captured
# 105000 p-values captured
# 106000 p-values captured
# 107000 p-values captured
# 108000 p-values captured
# 109000 p-values captured
# 110000 p-values captured
# 111000 p-values captured
# 112000 p-values captured
# 113000 p-values captured
# 114000 p-values captured
# 115000 p-values captured
# 116000 p-values captured
# 117000 p-values captured
# 118000 p-values captured
# 119000 p-values captured
# 120000 p-values captured
# 121000 p-values captured
# 122000 p-values captured
# 123000 p-values captured
# 124000 p-values captured
# 125000 p-values captured
# 126000 p-values captured
# 127000 p-values captured
# 128000 p-values captured
# 129000 p-values captured
# 130000 p-values captured
# 131000 p-values captured
# 132000 p-values captured
# 133000 p-values captured
# 134000 p-values captured
# 135000 p-values captured
# 136000 p-values captured
# 137000 p-values captured
# 138000 p-values captured
# 139000 p-values captured
# 140000 p-values captured
# 141000 p-values captured
# 142000 p-values captured
# 143000 p-values captured
# 144000 p-values captured
# 145000 p-values captured
# 146000 p-values captured
# 147000 p-values captured
# 148000 p-values captured
# 149000 p-values captured
# 150000 p-values captured
# 151000 p-values captured
# 152000 p-values captured
# 153000 p-values captured
# 154000 p-values captured
# 155000 p-values captured
# 156000 p-values captured
# 157000 p-values captured
# 158000 p-values captured
# 159000 p-values captured
# 160000 p-values captured
# 161000 p-values captured
# 162000 p-values captured
# 163000 p-values captured
# 164000 p-values captured
# 165000 p-values captured
# 166000 p-values captured
# 167000 p-values captured
# 168000 p-values captured
# 169000 p-values captured
# 170000 p-values captured
# 171000 p-values captured
# 172000 p-values captured
# 173000 p-values captured
# 174000 p-values captured
# 175000 p-values captured
# 176000 p-values captured
# 177000 p-values captured
# 178000 p-values captured
# 179000 p-values captured
# 180000 p-values captured
# 181000 p-values captured
# 182000 p-values captured
# 183000 p-values captured
# 184000 p-values captured
# 185000 p-values captured
# 186000 p-values captured
# 187000 p-values captured
# 188000 p-values captured
# 189000 p-values captured
# 190000 p-values captured
# 191000 p-values captured
# 192000 p-values captured
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/numerictypes.py in issubclass_(arg1, arg2)
#     322     try:
# --> 323         return issubclass(arg1, arg2)
#     324     except TypeError:
#
# TypeError: issubclass() arg 1 must be a class
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7427cb5ffd1b> in <module>
#      13                 pass
#      14             else:
# ---> 15                 df_stats = df_stats.append(extract, ignore_index=True)
#      16             count += 1
#      17
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7745         else:
#    7746             to_concat = [self, other]
# -> 7747         return concat(
#    7748             to_concat,
#    7749             ignore_index=ignore_index,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     285     )
#     286
# --> 287     return op.get_result()
#     288
#     289
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     500                 mgrs_indexers.append((obj._mgr, indexers))
#     501
# --> 502             new_data = concatenate_block_managers(
#     503                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy,
#     504             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      77         else:
#      78             b = make_block(
# ---> 79                 _concatenate_join_units(join_units, concat_axis, copy=copy,),
#      80                 placement=placement,
#      81             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     312         raise AssertionError("Concatenating join units along axis0")
#     313
# --> 314     empty_dtype, upcasted_na = _get_empty_dtype_and_na(join_units)
#     315
#     316     to_concat = [
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/concat.py in _get_empty_dtype_and_na(join_units)
#     404             upcast_cls = dtype.subtype.name
#     405         elif is_float_dtype(dtype) or is_numeric_dtype(dtype):
# --> 406             upcast_cls = dtype.name
#     407         else:
#     408             upcast_cls = "float"
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     333
#     334     # append bit counts
# --> 335     if _name_includes_bit_suffix(dtype):
#     336         name += "{}".format(dtype.itemsize * 8)
#     337
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/_dtype.py in _name_includes_bit_suffix(dtype)
#     312         # implied
#     313         return False
# --> 314     elif np.issubdtype(dtype, np.flexible) and _isunsized(dtype):
#     315         # unspecified
#     316         return False
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     385
#     386     """
# --> 387     if not issubclass_(arg1, generic):
#     388         arg1 = dtype(arg1).type
#     389     if not issubclass_(arg2, generic):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/numerictypes.py in issubclass_(arg1, arg2)
#     321     """
#     322     try:
# --> 323         return issubclass(arg1, arg2)
#     324     except TypeError:
#     325         return False
#
# KeyboardInterrupt:

# %%
df_stats.to_csv(out_path + 'stats_all_w_param.csv')

# %% [markdown]
# #### Recalcuating p-values, accounting for rounding errors

# %%
df_stats
# Out:
#                  File                          Original Type  Param1 Param2  \
# 0       614337945.xml   t   (41)   = 4.10,    p   < .01    t    41.0   None
# 1       614337945.xml  t   (41)   = −3.56,    p   < .01    t    41.0   None
# 2       614337945.xml   t   (41)   = 8.21,    p   < .01    t    41.0   None
# 3       614337945.xml   t   (41)   = 4.82,    p   < .01    t    41.0   None
# 4       614337945.xml  t   (41)   = −2.57,    p   < .01    t    41.0   None
# ...               ...                               ...  ...     ...    ...
# 197786  614478460.xml          t(99) = 42.24, p < .0001    t    99.0   None
# 197787  614338318.xml       F(9, 214) = 3.84, p < .0001    f     9.0    214
# 197788  614338318.xml         F(9, 240) = 0.94, p = .50    f     9.0    240
# 197789  614338318.xml       F(3, 236) = 6.10, p = .0005    f     3.0    236
# 197790  614338318.xml         F(3, 236) = 1.61, p = .19    f     3.0    236
#
#          Stat Sign  Reported p-value
# 0        4.10    <            0.0100
# 1       -3.56    <            0.0100
# 2        8.21    <            0.0100
# 3        4.82    <            0.0100
# 4       -2.57    <            0.0100
# ...       ...  ...               ...
# 197786  42.24    <            0.0001
# 197787   3.84    <            0.0001
# 197788   0.94    =            0.5000
# 197789   6.10    =            0.0005
# 197790   1.61    =            0.1900
#
# [197791 rows x 8 columns]

# %%
def recalculate(row):
    if row['Type'] == 't':
        return 1-stats.t.cdf(row['Stat'], row['Param1'])
    else:
        return 1-stats.f.cdf(row['Stat'], row['Param1'], row['Param2'])

# %%
df_stats['Recalculated p-value'] = df_stats.apply(lambda x: recalculate(x), axis=1)

# %% [markdown]
# Taking any rows that has a reported p-value around $[0.045, 0.05]$

# %%
close_df = df_stats[(df_stats['Reported p-value'] - 0.05 >= -0.005) & (df_stats['Reported p-value'] - 0.05 <= 0)]
close_df.shape
# Out:
# (30066, 9)

# %%
def recalculate_round_up(row):
    if row['Type'] == 't':
        return 1-stats.t.cdf(row['Stat']+0.1, row['Param1'])
    else:
        return 1-stats.f.cdf(row['Stat']+0.1, row['Param1'], row['Param2'])
    
def recalculate_round_down(row):
    if row['Type'] == 't':
        return 1-stats.t.cdf(row['Stat']-0.1, row['Param1'])
    else:
        return 1-stats.f.cdf(row['Stat']-0.1, row['Param1'], row['Param2'])

# %%
close_df['Stat+0.1'] = close_df.apply(lambda x: recalculate_round_up(x), axis=1)
close_df['Stat-0.1'] = close_df.apply(lambda x: recalculate_round_down(x), axis=1)
# Out:
# <ipython-input-35-cedd26c7be4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_df['Stat+0.1'] = close_df.apply(lambda x: recalculate_round_up(x), axis=1)
# <ipython-input-35-cedd26c7be4c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_df['Stat-0.1'] = close_df.apply(lambda x: recalculate_round_down(x), axis=1)

# %%
close_df[close_df['Type'] == 'f'].shape
# Out:
# (20382, 9)

# %% [markdown]
# From those rows with close to 0.05 p-values, reculculated and see which ones are mismatching. Looking at F-test only because t-scores are not yet corrected.

# %%
mismatch_df = close_df[(close_df['Recalculated p-value'] >=0.05) & (close_df['Type']=='f')]
mismatch_df.shape
# Out:
# (3085, 11)

# %%
mismatch_df[(mismatch_df['Stat+0.1'] < 0.05) | (mismatch_df['Stat-0.1'] < 0.05)]
# Out:
#                   File                       Original Type  Param1 Param2  \
# 25       614357009.xml        F(2, 57) = 3.1, p = .05    f     2.0     57
# 351      614317829.xml     F(1, 48) = 4.02, p   = .05    f     1.0     48
# 586      614496153.xml       F(2, 95) = 3.01, p = .05    f     2.0     95
# 718      614307900.xml  F(1, 39)   = 4.05,  p   < .05    f     1.0     39
# 784     1753445757.xml      F(2, 416) = 2.98, p = .05    f     2.0    416
# ...                ...                            ...  ...     ...    ...
# 197100  1685750389.xml      F(1, 114) = 3.88, p = .05    f     1.0    114
# 197244   614332498.xml      F(4, 212) = 2.37, p = .05    f     4.0    212
# 197388   614404428.xml       F(2, 27) = 3.33, p < .05    f     2.0     27
# 197588   614320914.xml     F(2, 80) = 3.02, p   = .05    f     2.0     80
# 197719   614298851.xml      F(1, 154) = 3.87, p < .05    f     1.0    154
#
#         Stat Sign  Reported p-value  Recalculated p-value  Stat+0.1  Stat-0.1
# 25      3.10    =              0.05              0.052723  0.048183  0.057707
# 351     4.02    =              0.05              0.050621  0.047942  0.053464
# 586     3.01    =              0.05              0.054016  0.049172  0.059348
# 718     4.05    <              0.05              0.051114  0.048462  0.053926
# 784     2.98    =              0.05              0.051878  0.047009  0.057255
# ...      ...  ...               ...                   ...       ...       ...
# 197100  3.88    =              0.05              0.051290  0.048429  0.054333
# 197244  2.37    =              0.05              0.053632  0.045759  0.062806
# 197388  3.33    <              0.05              0.050977  0.047058  0.055247
# 197588  3.02    =              0.05              0.054398  0.049573  0.059705
# 197719  3.87    <              0.05              0.050953  0.048085  0.054005
#
# [1048 rows x 11 columns]

# %% [markdown]
# Also to note that subtracting 0.1 from the statistic did not help the calculation.
